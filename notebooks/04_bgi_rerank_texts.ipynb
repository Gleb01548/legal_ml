# %%
import os

if "src" not in os.listdir():
    os.chdir("../")

# %%
import pandas as pd
from tqdm import tqdm
from qdrant_client import QdrantClient, models
from FlagEmbedding import FlagLLMReranker

from src.conf import url_qdrant


tqdm.pandas()

# %% [markdown]
# https://github.com/qdrant/workshop-ultimate-hybrid-search/blob/main/notebooks/02-hybrid-search.ipynb

# %% [markdown]
# ### Анализ работы разных поисков и реранков

# %%
qdrant_client = QdrantClient(url_qdrant)
collection_name = "911_hybrid_rating_points"

# %%
def convert_texts(text: list):
    st = ""
    for index, text in enumerate(text):
        st += f"Документ {index+1}"
        st += "\n\n\n"
        st += text
        st += "\n\n\n"
    return st


def search_data(collection_name, point, reranker_bge=None, reranker_gemma=None, n=10):
    vector = point.vector
    question = point.payload["question"]

    # запрос для разряженного вектора
    sparse = models.Prefetch(
        query=models.SparseVector(
            indices=vector["text-sparse"].indices,
            values=vector["text-sparse"].values,
        ),
        using="text-sparse",
        limit=100,
    )

    # запрос для разряженного вектора
    sparse_1000 = models.Prefetch(
        query=models.SparseVector(
            indices=vector["text-sparse"].indices,
            values=vector["text-sparse"].values,
        ),
        using="text-sparse",
        limit=1000,
    )

    # Запрос для плотного вектора
    dense = models.Prefetch(query=vector["dense"], using="dense", limit=100)

    # Запрос для плотного вектора 1000
    dense_1000 = models.Prefetch(query=vector["dense"], using="dense", limit=1000)

    # Запрашиваем 1000 по плотным векторам из них 100 по разряженным
    dence_sparse = models.Prefetch(
        prefetch=[dense_1000],
        query=models.SparseVector(
            indices=vector["text-sparse"].indices,
            values=vector["text-sparse"].values,
        ),
        using="text-sparse",
        limit=100,
    )

    # Запрашиваем 1000 по разряженным векторам из них 100 по плотным
    sparce_dense = models.Prefetch(
        prefetch=[sparse_1000], query=vector["dense"], using="dense", limit=100
    )

    ## Запрашиваем данные

    record = {}
    record["question"] = question

    if reranker_bge or reranker_gemma:
        record["model_rerank_type"] = [reranker_bge.model_name_or_path, reranker_gemma.model_name_or_path]

    for name_search_type, search_type in [
        ("dense", [dense]),
        ("sparse", [sparse]),
        ("sparse+dense", [sparse, dense]),
        ("sparce_dense", [sparce_dense]),
        ("dence_sparse", [dence_sparse]),
    ]:
        point = qdrant_client.query_points(
            collection_name=collection_name,
            prefetch=search_type,
            limit=100,
            query=models.FusionQuery(
                fusion=models.Fusion.RRF,
            ),
            timeout=1000,
        ).points

        texts = [i.payload["question"] for i in point[1:]]
        record[name_search_type] = convert_texts(texts[:n])
        record[f"{name_search_type}_len"] = sum([len(i) for i in texts[:n]])

        if reranker_bge:
            score = reranker_bge.compute_score([[question, i] for i in texts])
            texts_score = sorted(
                [(text, score) for text, score in zip(texts, score)],
                key=lambda x: x[1],
                reverse=True,
            )[:n]
            texts = [i[0] for i in texts_score]
            record[f"{name_search_type}_reranker_bge"] = convert_texts(texts)
            record[f"{name_search_type}_reranker_bge_len"] = sum([len(i) for i in texts])
        
        if reranker_gemma:
            score = reranker_gemma.compute_score([[question, i] for i in texts])
            texts_score = sorted(
                [(text, score) for text, score in zip(texts, score)],
                key=lambda x: x[1],
                reverse=True,
            )[:n]
            texts = [i[0] for i in texts_score]
            record[f"{name_search_type}_reranker_gemma"] = convert_texts(texts)
            record[f"{name_search_type}_reranker_gemma_len"] = sum([len(i) for i in texts])
            
    return record

# %%
def get_point(collection_name, n):
    return qdrant_client.query_points(
        collection_name=collection_name,
        query=models.SampleQuery(sample=models.Sample.RANDOM),
        limit=n,
        with_vectors=True,
    ).points

# %%
points = get_point(collection_name, n=20)
reranker_gemma = FlagLLMReranker("BAAI/bge-reranker-v2-gemma", use_fp16=True)
reranker_bge = FlagLLMReranker("BAAI/bge-reranker-v2-m3", use_fp16=True)

records = []
for point in tqdm(points):
    records.append(search_data(collection_name="911_hybrid", point=point, n=5, reranker_gemma=reranker_gemma, reranker_bge=reranker_bge))

pd.DataFrame(records).to_csv("./data/interim/rag_results/rag_results.csv")
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# If you want to use `XLMRobertaLMHeadModel` as a standalone, add `is_decoder=True.`
# Some weights of XLMRobertaForCausalLM were not initialized from the model checkpoint at BAAI/bge-reranker-v2-m3 and are newly initialized: ['lm_head.bias', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.layer_norm.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/20 [00:00<?, ?it/s]You're using a XLMRobertaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# 100%|██████████| 7/7 [00:02<00:00,  2.80it/s]
# You're using a GemmaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# 100%|██████████| 1/1 [00:01<00:00,  1.08s/it]
# 100%|██████████| 7/7 [00:00<00:00, 25.31it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.84it/s]
# 100%|██████████| 7/7 [00:00<00:00, 33.56it/s]
# 100%|██████████| 1/1 [00:00<00:00, 25.97it/s]
# 100%|██████████| 7/7 [00:00<00:00, 32.79it/s]
# 100%|██████████| 1/1 [00:00<00:00, 32.17it/s]
# 100%|██████████| 7/7 [00:00<00:00, 38.27it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.09it/s]
# 100%|██████████| 7/7 [00:00<00:00, 23.22it/s]]
# 100%|██████████| 1/1 [00:00<00:00, 13.52it/s]
# 100%|██████████| 7/7 [00:00<00:00,  8.79it/s]
# 100%|██████████| 1/1 [00:00<00:00, 10.64it/s]
# 100%|██████████| 7/7 [00:00<00:00, 16.47it/s]
# 100%|██████████| 1/1 [00:00<00:00, 11.06it/s]
# 100%|██████████| 7/7 [00:00<00:00, 20.69it/s]
# 100%|██████████| 1/1 [00:00<00:00, 10.89it/s]
# 100%|██████████| 7/7 [00:00<00:00, 23.79it/s]
# 100%|██████████| 1/1 [00:00<00:00, 16.07it/s]
# 100%|██████████| 7/7 [00:00<00:00, 19.34it/s]]
# 100%|██████████| 1/1 [00:00<00:00, 13.20it/s]
# 100%|██████████| 7/7 [00:00<00:00, 11.92it/s]
# 100%|██████████| 1/1 [00:00<00:00, 10.15it/s]
# 100%|██████████| 7/7 [00:00<00:00, 14.43it/s]
# 100%|██████████| 1/1 [00:00<00:00,  9.08it/s]
# 100%|██████████| 7/7 [00:00<00:00, 17.56it/s]
# 100%|██████████| 1/1 [00:00<00:00, 10.17it/s]
# 100%|██████████| 7/7 [00:00<00:00, 16.57it/s]
# 100%|██████████| 1/1 [00:00<00:00, 10.19it/s]
# 100%|██████████| 7/7 [00:00<00:00, 17.59it/s]]
# 100%|██████████| 1/1 [00:00<00:00,  9.57it/s]
# 100%|██████████| 7/7 [00:01<00:00,  6.38it/s]
# 100%|██████████| 1/1 [00:00<00:00,  8.97it/s]
# 100%|██████████| 7/7 [00:00<00:00,  8.79it/s]
# 100%|██████████| 1/1 [00:00<00:00, 10.11it/s]
# 100%|██████████| 7/7 [00:00<00:00, 10.92it/s]
# 100%|██████████| 1/1 [00:00<00:00, 10.34it/s]
# 100%|██████████| 7/7 [00:00<00:00, 13.93it/s]
# 100%|██████████| 1/1 [00:00<00:00,  8.27it/s]
# 100%|██████████| 7/7 [00:00<00:00, 22.77it/s]]
# 100%|██████████| 1/1 [00:00<00:00, 29.72it/s]
# 100%|██████████| 7/7 [00:00<00:00, 14.24it/s]
# 100%|██████████| 1/1 [00:00<00:00, 10.47it/s]
# 100%|██████████| 7/7 [00:00<00:00, 17.53it/s]
# 100%|██████████| 1/1 [00:00<00:00, 11.11it/s]
# 100%|██████████| 7/7 [00:00<00:00, 20.58it/s]
# 100%|██████████| 1/1 [00:00<00:00, 10.77it/s]
# 100%|██████████| 7/7 [00:00<00:00, 23.96it/s]
# 100%|██████████| 1/1 [00:00<00:00, 16.67it/s]
# 100%|██████████| 7/7 [00:00<00:00, 15.78it/s]]
# 100%|██████████| 1/1 [00:00<00:00, 10.54it/s]
# 100%|██████████| 7/7 [00:00<00:00,  8.04it/s]
# 100%|██████████| 1/1 [00:00<00:00,  7.14it/s]
# 100%|██████████| 7/7 [00:00<00:00, 10.07it/s]
# 100%|██████████| 1/1 [00:00<00:00,  8.80it/s]
# 100%|██████████| 7/7 [00:00<00:00, 14.00it/s]
# 100%|██████████| 1/1 [00:00<00:00,  8.90it/s]
# 100%|██████████| 7/7 [00:00<00:00, 14.04it/s]
# 100%|██████████| 1/1 [00:00<00:00,  9.03it/s]
# 100%|██████████| 7/7 [00:00<00:00, 31.07it/s]]
# 100%|██████████| 1/1 [00:00<00:00, 30.56it/s]
# 100%|██████████| 7/7 [00:00<00:00, 26.59it/s]
# 100%|██████████| 1/1 [00:00<00:00, 17.69it/s]
# 100%|██████████| 7/7 [00:00<00:00, 28.52it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.69it/s]
# 100%|██████████| 7/7 [00:00<00:00, 28.10it/s]
# 100%|██████████| 1/1 [00:00<00:00, 10.15it/s]
# 100%|██████████| 7/7 [00:00<00:00, 28.61it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.92it/s]
# 100%|██████████| 7/7 [00:00<00:00, 27.36it/s]]
# 100%|██████████| 1/1 [00:00<00:00, 16.80it/s]
# 100%|██████████| 7/7 [00:00<00:00, 20.95it/s]
# 100%|██████████| 1/1 [00:00<00:00, 11.18it/s]
# 100%|██████████| 7/7 [00:00<00:00, 27.01it/s]
# 100%|██████████| 1/1 [00:00<00:00, 19.22it/s]
# 100%|██████████| 7/7 [00:00<00:00, 26.40it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.14it/s]
# 100%|██████████| 7/7 [00:00<00:00, 26.63it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.05it/s]
# 100%|██████████| 7/7 [00:00<00:00, 31.83it/s]]
# 100%|██████████| 1/1 [00:00<00:00, 30.51it/s]
# 100%|██████████| 7/7 [00:00<00:00, 11.01it/s]
# 100%|██████████| 1/1 [00:00<00:00,  6.70it/s]
# 100%|██████████| 7/7 [00:00<00:00, 13.38it/s]
# 100%|██████████| 1/1 [00:00<00:00,  6
/s]
# 100%|██████████| 7/7 [00:00<00:00, 27.77it/s]
# 100%|██████████| 1/1 [00:00<00:00, 16.04it/s]
# 100%|██████████| 20/20 [01:56<00:00,  5.83s/it]

# %%
records[0]
# Out:
# {'question': 'Можно ли снять 14 б и через какое время',
#  'model_rerank_type': ['BAAI/bge-reranker-v2-m3',
#   'BAAI/bge-reranker-v2-gemma'],
#  'dense': 'Документ 1\n\n\nКак снять ст 14 б куда идти  и что писать.\n\n\nДокумент 2\n\n\nКак снять статью 14 б что надо для этого сделать и куда оброщаться.\n\n\nДокумент 3\n\n\nЗдравствуйте. Списали со службы по ст.18 б. через сколько её можно снять?\n\n\nДокумент 4\n\n\nМожно потом снять ст.15 и если можно то по истечении какого срока?\n\n\nДокумент 5\n\n\nХочу снять диагноз 14 б.\n\n\n',
#  'dense_len': 272,
#  'dense_reranker_bge': 'Документ 1\n\n\nЯ собираюсь в отпуск с последующим увольнением.  Могут ли меня заставить отрабатывать 14 дней?\n\n\nДокумент 2\n\n\nЯ собираюсь в очередной отпуск с последующим увольнением.  Могут ли заставить меня отрабатывать 14 дней?\n\n\nДокумент 3\n\n\nВопрос: могу ли я пойти в отпуск на 14 дней и и следующим днем после отпуска  уволиться по собственному желанию?\n\n\nДокумент 4\n\n\nКакой срок на это отпускается?\n\n\nДокумент 5\n\n\nПри увольнении должен ли я отработать 14 дней если срок трудового договора  закончился.\n\n\n',
#  'dense_reranker_bge_len': 427,
#  'dense_reranker_gemma': 'Документ 1\n\n\nПри увольнении должен ли я отработать 14 дней если срок трудового договора  закончился.\n\n\nДокумент 2\n\n\nВопрос: могу ли я пойти в отпуск на 14 дней и и следующим днем после отпуска  уволиться по собственному желанию?\n\n\nДокумент 3\n\n\nЯ собираюсь в очередной отпуск с последующим увольнением.  Могут ли заставить меня отрабатывать 14 дней?\n\n\nДокумент 4\n\n\nЯ собираюсь в отпуск с последующим увольнением.  Могут ли меня заставить отрабатывать 14 дней?\n\n\nДокумент 5\n\n\nКакой срок на это отпускается?\n\n\n',
#  'dense_reranker_gemma_len': 427,
#  'sparse': 'Документ 1\n\n\nКак снять статью 14 б и возможно ли это?\n\n\nДокумент 2\n\n\nКак снять статью 14 б что надо для этого сделать и куда оброщаться.\n\n\nДокумент 3\n\n\nМожно ли снять в 21 год статью 14 б? меня сняли с учета, но на работы не могу устроиться толком из за этой статьи, заранее спасибо:)\n\n\nДокумент 4\n\n\nКак снять статью 14 б в военном билете?\n\n\nДокумент 5\n\n\nКак снять ст 14 б куда идти  и что писать.\n\n\n',
#  'sparse_len': 320,
#  'sparse_reranker_bge': 'Документ 1\n\n\nКак снять статью 14 б в военном билете? Справка есть что здоров в военкомате говорят, что эта справка им не нужна и статью не снимут! Что делать?\n\n\nДокумент 2\n\n\nУ меня такая проблема я 14 летний и у меня на книжке лежат деньги как я смогу их снять?\n\n\nДокумент 3\n\n\nМне 14 лет, хочу снять квартиру на сутки,  а вопрос таков, могу ли я ее снять/ или нет?\n\n\nДокумент 4\n\n\nРебенку 14 лет. На ее имя открыт счет от продажи земельного участка. Можно ли снять с этого счета деньги?\n\n\nДокумент 5\n\n\nЗдравствуйте моя мама присылает мне олименты за 2 месяца и у меня такой вопрос могу ли я снять олименты со с Бер. книжки если мне 14 лет.\n\n\n',
#  'sparse_reranker_bge_len': 561,
#  'sparse+dense_reranker_gemma_len': 1099,
#  'sparce_dense': 'Документ 1\n\n\nКак снять статью 14 б и возможно ли это?\n\n\nДокумент 2\n\n\nКак снять ст 14 б куда идти  и что писать.\n\n\nДокумент 3\n\n\nКак снять статью 14 б что надо для этого сделать и куда оброщаться.\n\n\nДокумент 4\n\n\nЗдравствуйте. Списали со службы по ст.18 б. через сколько её можно снять?\n\n\nДокумент 5\n\n\nКак можно снять статью в военном билете  14 б?\n\n\n',
#  'sparce_dense_len': 268,
#  'sparce_dense_reranker_bge': 'Документ 1\n\n\nМожно состатьей 14 б уйти на сво, у меня есть прова категория б, и есть опыт миханика\n\n\nДокумент 2\n\n\nУ меня срок кредитной карты истекает завтра 14/11. Можно ли её сдать не 14 а 15? И что будет?\n\n\nДокумент 3\n\n\nКак снять статью 18 б в 34 года.\n\n\nДокумент 4\n\n\nДень добрый, можно ли снять статью 18 б.\n\n\nДокумент 5\n\n\nХочу усыновить ребёнка а у меня статья 14 б.\n\n\n',
#  'sparce_dense_reranker_bge_len': 294,
#  'sparce_dense_reranker_gemma': 'Документ 1\n\n\nМожно состатьей 14 б уйти на сво, у меня есть прова категория б, и есть опыт миханика\n\n\nДокумент 2\n\n\nДень добрый, можно ли снять статью 18 б.\n\n\nДокумент 3\n\n\nУ меня срок кредитной карты истекает завтра 14/11. Можно ли её сдать не 14 а 15? И что будет?\n\n\nДокумент 4\n\n\nКак снять статью 18 б в 34 года.\n\n\nДокумент 5\n\n\nХочу усыновить ребёнка а у меня статья 14 б.\n\n\n',
#  'sparce_dense_reranker_gemma_len': 294,
#  'dence_sparse': 'Документ 1\n\n\nКак снять статью 14 б что надо для этого сделать и куда оброщаться.\n\n\nДокумент 2\n\n\nМожно ли снять в 21 год статью 14 б? меня сняли с учета, но на работы не могу устроиться толком из за этой статьи, заранее спасибо:)\n\n\nДокумент 3\n\n\nКак снять статью 14 б в военном билете?\n\n\nДокумент 4\n\n\nКак снять ст 14 б куда идти  и что писать.\n\n\nДокумент 5\n\n\nХочу снять диагноз 14 б.\n\n\n',
#  'dence_sparse_len': 304,
#  'dence_sparse_reranker_bge': 'Документ 1\n\n\nМожно состатьей 14 б уйти на сво, у меня есть прова категория б, и есть опыт миханика\n\n\nДокумент 2\n\n\nЯ не стою на учете просто в военнике стоит статья 14 б гр II, как снять? В снятии статьи в ПНД мне отказали. Что делать дальше?\n\n\nДокумент 3\n\n\nМне 48 лет имею водительские права кат в,с, .работал монтажником высотником на севере 12 лет, решил устроится дома а не как, так как у меня статья 14 б можно ли ее как то онулировать или убрать диагноз.\n\n\nДокумент 4\n\n\nМожно ли взять 14 пенсонных дней к отпуску, но разбив их на части без выходных суббот и воскресений?\n\n\nДокумент 5\n\n\nКак снять статью 18 б в 34 года.\n\n\n',
#  'dence_sparse_reranker_bge_len': 546,
#  'dence_sparse_reranker_gemma': 'Документ 1\n\n\nЯ не стою на учете просто в военнике стоит статья 14 б гр II, как снять? В снятии статьи в ПНД мне отказали. Что делать дальше?\n\n\nДокумент 2\n\n\nМне 48 лет имею водительские права кат в,с, .работал монтажником высотником на севере 12 лет, решил устроится дома а не как, так как у меня статья 14 б можно ли ее как то онулировать или убрать диагноз.\n\n\nДокумент 3\n\n\nМожно состатьей 14 б уйти на сво, у меня есть прова категория б, и есть опыт миханика\n\n\nДокумент 4\n\n\nКак снять статью 18 б в 34 года.\n\n\nДокумент 5\n\n\nМожно ли взять 14 пенсонных дней к отпуску, но разбив их на части без выходных суббот и воскресений?\n\n\n',
#  'dence_sparse_reranker_gemma_len': 546}

# %%
pd.DataFrame(records).to_excel("./data/interim/rag_results/rag_results.xlsx")

# %%
df_records = pd.DataFrame(records)

df_records.describe()
# Out:
#          dense_len  dense_reranker_bge_len  dense_reranker_gemma_len  \
# count    20.000000               20.000000                 20.000000
# mean   1319.650000             1615.800000               1615.800000
# std     865.405976             1064.339607               1064.339607
# min     272.000000              427.000000                427.000000
# 25%     570.250000              528.250000                528.250000
# 50%    1196.000000             1619.000000               1619.000000
# 75%    1738.750000             2433.750000               2433.750000
# max    3530.000000             3352.000000               3352.000000
#
#           sparse_len  sparse_reranker_bge_len  sparse_reranker_gemma_len  \
# count      20.000000                20.000000                  20.000000
# mean    57444.950000              6960.950000                6960.950000
# std     98807.369587             11117.203243               11117.203243
# min       320.000000               473.000000                 473.000000
# 25%      1859.500000              2520.000000                2520.000000
# 50%      5517.500000              3740.000000                3740.000000
# 75%     78195.500000              5497.250000                5497.250000
# max    405693.000000             50061.000000               50061.000000
#
#        sparse+dense_len  sparse+dense_reranker_bge_len  \
# count         20.000000                      20.000000
# mean       22906.950000                    8618.650000
# std        38329.211705                   22736.928356
# min          212.000000                     702.000000
# 25%         1519.500000                    1531.000000
# 50%         3767.500000                    3167.000000
# 75%        24859.500000                    4154.500000
# max       133145.000000                  103860.000000
#
#        sparse+dense_reranker_gemma_len  sparce_dense_len  \
# count                        20.000000         20.000000
# mean                       8618.650000       1650.000000
# std                       22736.928356       1166.488568
# min                         702.000000        268.000000
# 25%                        1531.000000        658.750000
# 50%                        3167.000000       1495.000000
# 75%                        4154.500000       1988.250000
# max                      103860.000000       4629.000000
#
#        sparce_dense_reranker_bge_len  sparce_dense_reranker_gemma_len  \
# count                      20.000000                        20.000000
# mean                     2326.800000                      2326.800000
# std                      1523.055917                      1523.055917
# min                       294.000000                       294.000000
# 25%                       888.500000                       888.500000
# 50%                      2353.500000                      2353.500000
# 75%                      3492.750000                      3492.750000
# max                      5235.000000                      5235.000000
#
#        dence_sparse_len  dence_sparse_reranker_bge_len  \
# count         20.000000                      20.000000
# mean        2834.800000                    2206.650000
# std         2422.867779                    1524.937558
# min          304.000000                     546.000000
# 25%          989.750000                     816.750000
# 50%         2102.000000                    1620.500000
# 75%         4598.250000                    3496.500000
# max         9692.000000                    5200.000000
#
#        dence_sparse_reranker_gemma_len
# count                        20.000000
# mean                       2206.650000
# std                        1524.937558
# min                         546.000000
# 25%                         816.750000
# 50%                        1620.500000
# 75%                        3496.500000
# max                        5200.000000
